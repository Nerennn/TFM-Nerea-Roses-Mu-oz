# %% [markdown]
# # **1. LIMPIEZA DE  DATOS**

# %% [markdown]
# Se hará:
# - Eliminar las columnas que no sean "id", "timestamp", "body"
# - Filtrar fechas del 28 de abril al 28 de mayo de 2025 (incluidos)
# - Eliminar tweets con entradas con "RT" (eliminación de retweets)
# - Añadir columna "blackout" con valores en 0 para luego codificar manualmente
# - Añadir columna "nombre"

# %% [markdown]
# PEDRO SÁNCHEZ

# %%
import pandas as pd

# Cargar el archivo CSV
file_path = "PEDRO SÁNCHEZ.csv"
df = pd.read_csv(file_path)

# Filtrar las columnas necesarias
df_filtered = df[["id", "timestamp", "body"]]

# Convertir la columna "timestamp" a formato datetime
df_filtered["timestamp"] = pd.to_datetime(df_filtered["timestamp"], errors="coerce")

# Filtrar las fechas entre el 28 de abril y el 28 de mayo (incluidos)
start_date = "2025-04-28"
end_date = "2025-05-29"
df_filtered = df_filtered[(df_filtered["timestamp"] >= start_date) & (df_filtered["timestamp"] <= end_date)]
# Eliminar las entradas cuyo cuerpo comience por "RT"
df_filtered = df_filtered[~df_filtered["body"].str.startswith("RT", na=False)]
print(df_filtered.shape)
blackout_values = pd.read_csv("PEDRO SÁNCHEZ_blackout_value.csv")
# Crear la nueva columna "blackout" y rellenarla con 0
df_filtered["blackout"] = blackout_values["blackout"].values
print(len(blackout_values["blackout"].values))
# Cargamos el los valores blackout
# Asignar los valores de blackout a la columna "blackout" como enteros
# Añadir la nueva columna "nombre" al inicio del DataFrame
df_filtered.insert(0, "nombre", "Pedro Sánchez")

# Guardar el archivo con el nuevo nombre
output_path = file_path.replace(".csv", "_filtered.csv")
df_filtered.to_csv(output_path, index=False, encoding="utf-8")
print(df_filtered.shape)
print(f"Archivo filtrado guardado en: {output_path}")
# Out:
# (78, 3)
# 78
# (78, 5)
# Archivo filtrado guardado en: PEDRO SÁNCHEZ_filtered.csv

# %% [markdown]
# SANTIAGO ABASCAL

# %%
import pandas as pd

# Cargar el archivo CSV
file_path = "ABASCAL.csv"
df = pd.read_csv(file_path)

# Filtrar las columnas necesarias
df_filtered = df[["id", "timestamp", "body"]]

# Convertir la columna "timestamp" a formato datetime
df_filtered["timestamp"] = pd.to_datetime(df_filtered["timestamp"], errors="coerce")

# Filtrar las fechas entre el 28 de abril y el 28 de mayo (incluidos)
start_date = "2025-04-28"
end_date = "2025-05-29"
df_filtered = df_filtered[(df_filtered["timestamp"] >= start_date) & (df_filtered["timestamp"] <= end_date)]

# Eliminar las entradas cuyo cuerpo comience por "RT"
df_filtered = df_filtered[~df_filtered["body"].str.startswith("RT", na=False)]

# Crear la nueva columna "blackout" y rellenarla con 0
df_filtered["blackout"] = 0
# Cargamos el los valores blackout
blackout_values = pd.read_csv("ABASCAL_blackout_value.csv")
# Asignar los valores de blackout a la columna "blackout"
df_filtered["blackout"] = blackout_values["blackout"].values
# Añadir la nueva columna "nombre" al inicio del DataFrame
df_filtered.insert(0, "nombre", "Santiago Abascal")

# Guardar el archivo con el nuevo nombre
output_path = file_path.replace(".csv", "_filtered.csv")
df_filtered.to_csv(output_path, index=False, encoding="utf-8")

print(f"Archivo filtrado guardado en: {output_path}")
# Out:
# Archivo filtrado guardado en: ABASCAL_filtered.csv

# %% [markdown]
# ALBERTO NUÑEZ FEIJÓO

# %%
import pandas as pd

# Cargar el archivo CSV
file_path = "FEIJÓO.csv"
df = pd.read_csv(file_path)

# Filtrar las columnas necesarias
df_filtered = df[["id", "timestamp", "body"]]

# Convertir la columna "timestamp" a formato datetime
df_filtered["timestamp"] = pd.to_datetime(df_filtered["timestamp"], errors="coerce")

# Filtrar las fechas entre el 28 de abril y el 28 de mayo (incluidos)
start_date = "2025-04-28"
end_date = "2025-05-29"
df_filtered = df_filtered[(df_filtered["timestamp"] >= start_date) & (df_filtered["timestamp"] <= end_date)]

# Eliminar las entradas cuyo cuerpo comience por "RT"
df_filtered = df_filtered[~df_filtered["body"].str.startswith("RT", na=False)]

# Crear la nueva columna "blackout" y rellenarla con 0
df_filtered["blackout"] = 0
# Cargamos el los valores blackout
blackout_values = pd.read_csv("FEIJÓO_blackout_value.csv")
# Asignar los valores de blackout a la columna "blackout"
df_filtered["blackout"] = blackout_values["blackout"].values
# Añadir la nueva columna "nombre" al inicio del DataFrame
df_filtered.insert(0, "nombre", "Feijóo")	

# Guardar el archivo con el nuevo nombre
output_path = file_path.replace(".csv", "_filtered.csv")
df_filtered.to_csv(output_path, index=False, encoding="utf-8")

print(f"Archivo filtrado guardado en: {output_path}")
# Out:
# Archivo filtrado guardado en: FEIJÓO_filtered.csv
# /tmp/ipykernel_59971/3153698797.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["timestamp"] = pd.to_datetime(df_filtered["timestamp"], errors="coerce")

# %% [markdown]
# PP

# %%
import pandas as pd

# Cargar el archivo CSV
file_path = "PP.csv"
df = pd.read_csv(file_path)

# Filtrar las columnas necesarias
df_filtered = df[["id", "timestamp", "body"]]

# Convertir la columna "timestamp" a formato datetime
df_filtered["timestamp"] = pd.to_datetime(df_filtered["timestamp"], errors="coerce")

# Filtrar las fechas entre el 28 de abril y el 28 de mayo (incluidos)
start_date = "2025-04-28"
end_date = "2025-05-29"
df_filtered = df_filtered[(df_filtered["timestamp"] >= start_date) & (df_filtered["timestamp"] <= end_date)]

# Eliminar las entradas cuyo cuerpo comience por "RT"
df_filtered = df_filtered[~df_filtered["body"].str.startswith("RT", na=False)]

# Crear la nueva columna "blackout" y rellenarla con 0
df_filtered["blackout"] = 0
# Cargamos el los valores blackout
blackout_values = pd.read_csv("PP_blackout_value.csv")
# Asignar los valores de blackout a la columna "blackout"
df_filtered["blackout"] = blackout_values["blackout"].values
# Añadir la nueva columna "nombre" al inicio del DataFrame
df_filtered.insert(0, "nombre", "PP")

# Guardar el archivo con el nuevo nombre
output_path = file_path.replace(".csv", "_filtered.csv")
df_filtered.to_csv(output_path, index=False, encoding="utf-8")

print(f"Archivo filtrado guardado en: {output_path}")
# Out:
# Archivo filtrado guardado en: PP_filtered.csv
# /tmp/ipykernel_59971/879211141.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["timestamp"] = pd.to_datetime(df_filtered["timestamp"], errors="coerce")

# %% [markdown]
# PSOE

# %%
import pandas as pd

# Cargar el archivo CSV
file_path = "PSOE.csv"
df = pd.read_csv(file_path)

# Filtrar las columnas necesarias
df_filtered = df[["id", "timestamp", "body"]]

# Convertir la columna "timestamp" a formato datetime
df_filtered["timestamp"] = pd.to_datetime(df_filtered["timestamp"], errors="coerce")

# Filtrar las fechas entre el 28 de abril y el 28 de mayo (incluidos)
start_date = "2025-04-28"
end_date = "2025-05-29"
df_filtered = df_filtered[(df_filtered["timestamp"] >= start_date) & (df_filtered["timestamp"] <= end_date)]

# Eliminar las entradas cuyo cuerpo comience por "RT"
df_filtered = df_filtered[~df_filtered["body"].str.startswith("RT", na=False)]

# Crear la nueva columna "blackout" y rellenarla con 0
df_filtered["blackout"] = 0
# Cargamos el los valores blackout
blackout_values = pd.read_csv("PSOE_blackout_value.csv")
# Asignar los valores de blackout a la columna "blackout"
df_filtered["blackout"] = blackout_values["blackout"].values
# Añadir la nueva columna "nombre" al inicio del DataFrame
df_filtered.insert(0, "nombre", "PSOE")

# Guardar el archivo con el nuevo nombre
output_path = file_path.replace(".csv", "_filtered.csv")
df_filtered.to_csv(output_path, index=False, encoding="utf-8")

print(f"Archivo filtrado guardado en: {output_path}")
# Out:
# Archivo filtrado guardado en: PSOE_filtered.csv
# /tmp/ipykernel_59971/1107339498.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["timestamp"] = pd.to_datetime(df_filtered["timestamp"], errors="coerce")

# %% [markdown]
# VOX

# %%
import pandas as pd

# Cargar el archivo CSV
file_path = "VOX.csv"
df = pd.read_csv(file_path)

# Filtrar las columnas necesarias
df_filtered = df[["id", "timestamp", "body"]]

# Convertir la columna "timestamp" a formato datetime
df_filtered["timestamp"] = pd.to_datetime(df_filtered["timestamp"], errors="coerce")

# Filtrar las fechas entre el 28 de abril y el 28 de mayo (incluidos)
start_date = "2025-04-28"
end_date = "2025-05-29"
df_filtered = df_filtered[(df_filtered["timestamp"] >= start_date) & (df_filtered["timestamp"] <= end_date)]

# Eliminar las entradas cuyo cuerpo comience por "RT"
df_filtered = df_filtered[~df_filtered["body"].str.startswith("RT", na=False)]

# Crear la nueva columna "blackout" y rellenarla con 0
df_filtered["blackout"] = 0
# Cargamos el los valores blackout
blackout_values = pd.read_csv("VOX_blackout_value.csv")
# Asignar los valores de blackout a la columna "blackout"
df_filtered["blackout"] = blackout_values["blackout"].values
# Añadir la nueva columna "nombre" al inicio del DataFrame
df_filtered.insert(0, "nombre", "VOX")

# Guardar el archivo con el nuevo nombre
output_path = file_path.replace(".csv", "_filtered.csv")
df_filtered.to_csv(output_path, index=False, encoding="utf-8")

print(f"Archivo filtrado guardado en: {output_path}")
# Out:
# Archivo filtrado guardado en: VOX_filtered.csv
# /tmp/ipykernel_59971/738346602.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["timestamp"] = pd.to_datetime(df_filtered["timestamp"], errors="coerce")

# %% [markdown]
# SUMAR

# %%
import pandas as pd

# Cargar el archivo CSV
file_path = "salidasumar.csv"
df = pd.read_csv(file_path)

# Crear la nueva columna "blackout" y rellenarla con 0
df["blackout"] = 0

# Renombrar las columnas existentes
df = df.rename(columns={
    "created": "timestamp",  # Renombrar "created" a "timestamp"
    "text": "body",          # Renombrar "text" a "body"
    "uri": "id"              # Usar el contenido de "uri" como "id"
})

# Eliminar la columna "author" si existe
if "author" in df.columns:
    df = df.drop(columns=["author"])
    print("Columna 'author' eliminada")

# Añadir la columna "nombre" con "Yolanda Díaz" y moverla al principio
df.insert(0, "nombre", "Sumar")
# Cargamos el los valores blackout
blackout_values = pd.read_csv("salidasumar_blackout_value.csv")
# Asignar los valores de blackout a la columna "blackout"
df["blackout"] = blackout_values["blackout"].values
# Guardar el archivo con el nuevo nombre
output_path = file_path.replace(".csv", "_filtered.csv")
df.to_csv(output_path, index=False, encoding="utf-8")

print(f"Archivo filtrado guardado en: {output_path}")
print(f"Columnas modificadas: {', '.join(df.columns.tolist())}")
# Out:
# Columna 'author' eliminada
# Archivo filtrado guardado en: salidasumar_filtered.csv
# Columnas modificadas: nombre, id, timestamp, body, blackout

# %% [markdown]
# YOLANDA DÍAZ

# %%
import pandas as pd

# Cargar el archivo CSV
file_path = "salidayolanda.csv"
df = pd.read_csv(file_path)

# Crear la nueva columna "blackout" y rellenarla con 0
df["blackout"] = 0

# Renombrar las columnas existentes
df = df.rename(columns={
    "created": "timestamp",  # Renombrar "created" a "timestamp"
    "text": "body",          # Renombrar "text" a "body"
    "uri": "id"              # Usar el contenido de "uri" como "id"
})

# Eliminar la columna "author" si existe
if "author" in df.columns:
    df = df.drop(columns=["author"])
    print("Columna 'author' eliminada")

# Añadir la columna "nombre" con "Yolanda Díaz" y moverla al principio
df.insert(0, "nombre", "Yolanda Díaz")
# Cargamos el los valores blackout
blackout_values = pd.read_csv("salidayolanda_blackout_value.csv")
# Asignar los valores de blackout a la columna "blackout"
df["blackout"] = blackout_values["blackout"].values
# Guardar el archivo con el nuevo nombre
output_path = file_path.replace(".csv", "_filtered.csv")
df.to_csv(output_path, index=False, encoding="utf-8")

print(f"Archivo filtrado guardado en: {output_path}")
print(f"Columnas modificadas: {', '.join(df.columns.tolist())}")
# Out:
# Columna 'author' eliminada
# Archivo filtrado guardado en: salidayolanda_filtered.csv
# Columnas modificadas: nombre, id, timestamp, body, blackout

# %% [markdown]
# AÑADIR UNA NUEVA COLUMNA SI/NO LÍDER EN TODAS LAS BASES

# %%
import pandas as pd
import os
import glob

def procesar_bases_datos():
    print("\n" + "="*70)
    print(" PROCESAMIENTO DE BASES DE DATOS - AÑADIR COLUMNA LÍDER ".center(70, "="))
    print("="*70 + "\n")
    
    # Directorio donde se encuentran las bases de datos
    directorio = "./"
    
    # Lista de perfiles que son líderes
    lideres = ["PEDRO SÁNCHEZ", "salidayolanda", "FEIJÓO", "ABASCAL"]
    
    # Buscar todos los archivos CSV filtrados
    patron_busqueda = os.path.join(directorio, "*_filtered.csv")
    archivos = glob.glob(patron_busqueda)
    
    if not archivos:
        print(f"No se encontraron archivos con el patrón '*_filtered.csv' en {directorio}")
        return
    
    print(f"Se encontraron {len(archivos)} archivos para procesar.")
    
    # Procesar cada archivo
    for archivo in archivos:
        nombre_archivo = os.path.basename(archivo)
        nombre_base = nombre_archivo.replace("_filtered.csv", "")
        
        print(f"\nProcesando: {nombre_archivo}")
        
        # Determinar si es líder o no
        es_lider = False
        for lider in lideres:
            if lider.lower() in nombre_base.lower():
                es_lider = True
                break
        
        valor_lider = "si" if es_lider else "no"
        print(f"  Clasificado como líder: {es_lider} -> valor: '{valor_lider}'")
        
        try:
            # Cargar el dataset
            df = pd.read_csv(archivo)
            
            # Verificar si existe la columna 'body'
            if 'body' not in df.columns:
                print(f"  ¡ADVERTENCIA! El archivo {nombre_archivo} no tiene columna 'body'")
                # Añadir la columna 'lider' al inicio
                df.insert(0, 'lider', valor_lider)
            else:
                # Obtener el índice de la columna 'body'
                indice_body = df.columns.get_loc('body')
                
                # Añadir la columna 'lider' justo antes de 'body'
                df.insert(indice_body, 'lider', valor_lider)
            
            # Nombre del nuevo archivo
            nuevo_archivo = os.path.join(directorio, nombre_base + "_filtered_lider.csv")
            
            # Guardar el dataframe modificado
            df.to_csv(nuevo_archivo, index=False)
            
            print(f"  Guardado como: {nombre_base}_filtered_lider.csv")
            print(f"  Dimensiones: {df.shape[0]} filas × {df.shape[1]} columnas")
            
        except Exception as e:
            print(f"  ERROR al procesar {nombre_archivo}: {e}")
    
    print("\nProcesamiento completado.")

# Ejecutar la función
if __name__ == "__main__":
    procesar_bases_datos()
# Out:
# ...
# ======= PROCESAMIENTO DE BASES DE DATOS - AÑADIR COLUMNA LÍDER =======
# ...
#
# Se encontraron 8 archivos para procesar.
#
# Procesando: VOX_filtered.csv
#   Clasificado como líder: False -> valor: 'no'
#   Guardado como: VOX_filtered_lider.csv
#   Dimensiones: 189 filas × 6 columnas
#
# Procesando: FEIJÓO_filtered.csv
#   Clasificado como líder: True -> valor: 'si'
#   Guardado como: FEIJÓO_filtered_lider.csv
#   Dimensiones: 79 filas × 6 columnas
#
# Procesando: ABASCAL_filtered.csv
#   Clasificado como líder: True -> valor: 'si'
#   Guardado como: ABASCAL_filtered_lider.csv
#   Dimensiones: 46 filas × 6 columnas
#
# Procesando: salidasumar_filtered.csv
#   Clasificado como líder: False -> valor: 'no'
#   Guardado como: salidasumar_filtered_lider.csv
#   Dimensiones: 163 filas × 6 columnas
#
# Procesando: salidayolanda_filtered.csv
#   Clasificado como líder: True -> valor: 'si'
#   Guardado como: salidayolanda_filtered_lider.csv
#   Dimensiones: 96 filas × 6 columnas
#
# ...

# %% [markdown]
# UNIÓN DE TODAS LAS BASES EN UN ARCHIVO CONJUNTO

# %%
import pandas as pd
import os
import glob

def unir_bases_datos():
    print("\n" + "="*70)
    print(" UNIÓN DE BASES DE DATOS EN ARCHIVO CONJUNTO ".center(70, "="))
    print("="*70 + "\n")
    
    # Directorio donde se encuentran las bases de datos
    directorio = "./"
    
    # Buscar todos los archivos CSV con el patrón "*_filtered_lider.csv"
    patron_busqueda = os.path.join(directorio, "*_filtered_lider.csv")
    archivos = glob.glob(patron_busqueda)
    
    if not archivos:
        print(f"No se encontraron archivos con el patrón '*_filtered_lider.csv' en {directorio}")
        return
    
    print(f"Se encontraron {len(archivos)} archivos para unir:")
    for idx, archivo in enumerate(archivos, 1):
        print(f"  {idx}. {os.path.basename(archivo)}")
    
    # Lista para almacenar los dataframes
    dfs = []
    total_filas = 0
    
    # Procesar cada archivo
    for archivo in archivos:
        nombre_archivo = os.path.basename(archivo)
        nombre_base = nombre_archivo.replace("_filtered_lider.csv", "")
        
        try:
            # Cargar el dataset
            df = pd.read_csv(archivo)
            
            # Añadir columna para identificar el origen
            df['origen'] = nombre_base
            
            # Almacenar el dataframe
            dfs.append(df)
            
            # Actualizar contador de filas
            total_filas += len(df)
            
            print(f"Cargado: {nombre_archivo} - {len(df)} filas")
            
        except Exception as e:
            print(f"ERROR al cargar {nombre_archivo}: {e}")
    
    if not dfs:
        print("No se pudo cargar ningún archivo. Operación abortada.")
        return
    
    # Unir todos los dataframes
    print("\nUniendo dataframes...")
    df_combinado = pd.concat(dfs, ignore_index=True)
    
    # Verificar que la unión se realizó correctamente
    print(f"Dataframe combinado: {df_combinado.shape[0]} filas × {df_combinado.shape[1]} columnas")
    
    if df_combinado.shape[0] != total_filas:
        print("¡ADVERTENCIA! El número de filas no coincide con la suma esperada.")
    
    # Ruta del archivo de salida
    archivo_salida = os.path.join(directorio, "base_conjunta.csv")
    
    # Guardar el dataframe combinado
    df_combinado.to_csv(archivo_salida, index=False)
    
    print(f"\nBase de datos conjunta guardada como: {archivo_salida}")
    print(f"La base conjunta contiene datos de {len(dfs)} archivos originales.")
    
    # Mostrar información de las columnas
    print("\nColumnas en la base conjunta:")
    for col in df_combinado.columns:
        print(f"  - {col}")
    
    # Mostrar distribución de orígenes
    print("\nDistribución por origen:")
    distribucion = df_combinado['origen'].value_counts().sort_values(ascending=False)
    for origen, count in distribucion.items():
        print(f"  - {origen}: {count} filas")
    
    print("\nProceso completado con éxito.")

# Ejecutar la función
if __name__ == "__main__":
    unir_bases_datos()
# Out:
# ...
# ============ UNIÓN DE BASES DE DATOS EN ARCHIVO CONJUNTO =============
# ...
#
# Se encontraron 8 archivos para unir:
#   1. PSOE_filtered_lider.csv
#   2. salidayolanda_filtered_lider.csv
#   3. VOX_filtered_lider.csv
#   4. PP_filtered_lider.csv
#   5. salidasumar_filtered_lider.csv
#   6. FEIJÓO_filtered_lider.csv
#   7. PEDRO SÁNCHEZ_filtered_lider.csv
#   8. ABASCAL_filtered_lider.csv
# Cargado: PSOE_filtered_lider.csv - 313 filas
# Cargado: salidayolanda_filtered_lider.csv - 96 filas
# Cargado: VOX_filtered_lider.csv - 189 filas
# Cargado: PP_filtered_lider.csv - 123 filas
# Cargado: salidasumar_filtered_lider.csv - 163 filas
# Cargado: FEIJÓO_filtered_lider.csv - 79 filas
# Cargado: PEDRO SÁNCHEZ_filtered_lider.csv - 78 filas
# Cargado: ABASCAL_filtered_lider.csv - 46 filas
#
# Uniendo dataframes...
# Dataframe combinado: 1087 filas × 7 columnas
#
# Base de datos conjunta guardada como: ./base_conjunta.csv
# La base conjunta contiene datos de 8 archivos originales.
#
# ...

# %% [markdown]
# # **2. ANÁLISIS EXPLORATORIO**

# %% [markdown]
# ESTADÍSTICAS DESCRIPTIVAS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from collections import Counter
import re
import nltk
from nltk.corpus import stopwords

# Configurar pandas para mostrar todas las filas sin truncamiento
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.expand_frame_repr', False)

# Crear una lista con todos los archivos CSV filtrados
archivos = [
    "PEDRO SÁNCHEZ_filtered.csv",
    "ABASCAL_filtered.csv",
    "FEIJÓO_filtered.csv",
    "PP_filtered.csv",
    "PSOE_filtered.csv",
    "VOX_filtered.csv",
    "salidasumar_filtered.csv",
    "salidayolanda_filtered.csv"
]

# Función para obtener la columna de fecha del dataset
def get_date_column(df):
    if 'timestamp' in df.columns:
        return 'timestamp'
    elif 'created' in df.columns:
        return 'created'
    elif 'date' in df.columns:
        return 'date'
    return None

# Función para obtener la columna de contenido del dataset
def get_content_column(df):
    if 'body' in df.columns:
        return 'body'
    elif 'text' in df.columns:
        return 'text'
    return None

# Cargar todos los datasets en un diccionario
datasets = {}
for archivo in archivos:
    nombre = archivo.replace("_filtered.csv", "")
    ruta = f"c:/Users/nerea/Desktop/Bases de datos TFM/{archivo}"
    try:
        datasets[nombre] = pd.read_csv(ruta)
        print(f"Cargado {nombre}: {len(datasets[nombre])} tweets")
        print(f"  Columnas disponibles: {', '.join(datasets[nombre].columns.tolist())}")
    except Exception as e:
        print(f"Error al cargar {nombre}: {e}")

# Crear un archivo de texto para guardar los resultados completos
with open('estadisticas_exploratorias.txt', 'w', encoding='utf-8') as f:
    # Ver estadísticas básicas para cada dataset
    for nombre, df in datasets.items():
        info = f"\n{'='*50}\n"
        info += f"ESTADÍSTICAS PARA: {nombre}\n"
        info += f"{'='*50}\n"
        info += f"Número total de tweets: {len(df)}\n"
        
        # Obtener la columna de fecha adecuada
        date_col = get_date_column(df)
        if date_col:
            info += f"Período de tiempo: {df[date_col].min()} a {df[date_col].max()}\n"
        else:
            info += "No se encontró columna de fecha/hora\n"
        
        # Obtener la columna de contenido adecuada
        content_col = get_content_column(df)
        if content_col:
            info += f"Longitud media de tweets: {df[content_col].str.len().mean():.2f} caracteres\n"
            info += f"Tweet más corto: {df[content_col].str.len().min()} caracteres\n"
            info += f"Tweet más largo: {df[content_col].str.len().max()} caracteres\n"
        else:
            info += "No se encontró columna de contenido de tweet\n"
            
        # Escribir en el archivo y mostrar en pantalla
        f.write(info)
        print(info)

print(f"\nEstadísticas guardadas en el archivo: estadisticas_exploratorias.txt")
# Out:
# Error al cargar PEDRO SÁNCHEZ: [Errno 2] No such file or directory: 'c:/Users/nerea/Desktop/Bases de datos TFM/PEDRO SÁNCHEZ_filtered.csv'
# Error al cargar ABASCAL: [Errno 2] No such file or directory: 'c:/Users/nerea/Desktop/Bases de datos TFM/ABASCAL_filtered.csv'
# Error al cargar FEIJÓO: [Errno 2] No such file or directory: 'c:/Users/nerea/Desktop/Bases de datos TFM/FEIJÓO_filtered.csv'
# Error al cargar PP: [Errno 2] No such file or directory: 'c:/Users/nerea/Desktop/Bases de datos TFM/PP_filtered.csv'
# Error al cargar PSOE: [Errno 2] No such file or directory: 'c:/Users/nerea/Desktop/Bases de datos TFM/PSOE_filtered.csv'
# Error al cargar VOX: [Errno 2] No such file or directory: 'c:/Users/nerea/Desktop/Bases de datos TFM/VOX_filtered.csv'
# Error al cargar salidasumar: [Errno 2] No such file or directory: 'c:/Users/nerea/Desktop/Bases de datos TFM/salidasumar_filtered.csv'
# ...

# %% [markdown]
# # **3. ANÁLISIS TEMPORAL**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import matplotlib.dates as mdates

# Cargar los datos
df_abascal = pd.read_csv("ABASCAL_filtered_lider.csv")
df_vox = pd.read_csv("VOX_filtered_lider.csv")
df_yolanda = pd.read_csv("salidayolanda_filtered_lider.csv")
df_sumar = pd.read_csv("salidasumar_filtered_lider.csv")
df_psoe = pd.read_csv("PSOE_filtered_lider.csv")
df_pedro = pd.read_csv("PEDRO SÁNCHEZ_filtered_lider.csv")
df_pp = pd.read_csv("PP_filtered_lider.csv")
df_feijoo = pd.read_csv("FEIJÓO_filtered_lider.csv")

# Convertir la columna timestamp a datetime
for df in [df_abascal, df_vox, df_yolanda, df_sumar, df_psoe, df_pedro, df_pp, df_feijoo]:
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    # Crear una columna de fecha sin hora
    df['fecha'] = df['timestamp'].dt.date
    # Filtra blackout sea 1

# Combinar todos los dataframes
df_abascal['partido'] = 'VOX'
df_abascal = df_abascal[df_abascal["blackout"] == 1]
df_vox['partido'] = 'VOX'
df_vox = df_vox[df_vox["blackout"] == 1]
df_yolanda['partido'] = 'Sumar'
df_yolanda = df_yolanda[df_yolanda["blackout"] == 1]
df_sumar['partido'] = 'Sumar'
df_sumar = df_sumar[df_sumar["blackout"] == 1]
df_psoe['partido'] = 'PSOE'
df_psoe = df_psoe[df_psoe["blackout"] == 1]
df_pedro['partido'] = 'PSOE'
df_pedro = df_pedro[df_pedro["blackout"] == 1]
df_pp['partido'] = 'PP'
df_pp = df_pp[df_pp["blackout"] == 1]
df_feijoo['partido'] = 'PP'
df_feijoo = df_feijoo[df_feijoo["blackout"] == 1]
print(df_abascal.head())

# Definir listas para partidos y líderes
partidos = [df_vox, df_sumar, df_psoe, df_pp]
lideres = [df_abascal, df_yolanda, df_pedro, df_feijoo]
nombres_partidos = ['VOX', 'Sumar', 'PSOE', 'PP']
nombres_lideres = ['Abascal', 'Y. Díaz', 'P. Sánchez', 'Feijóo']

# Definir colores similares para partidos y líderes
colores_partidos = ['darkgreen', 'purple', 'red', 'blue']
colores_lideres = ['lightgreen', 'plum', 'lightcoral', 'lightskyblue']

# Filtrar tweets relacionados con el apagón (blackout = 1)
def contar_tweets_por_fecha(df, fecha_inicio, fecha_fin):
    return df[(df['fecha'] >= fecha_inicio) & (df['fecha'] <= fecha_fin)].shape[0]

# Definir rango de fechas para el histograma (periodo del apagón)
fecha_inicio = pd.to_datetime('2025-04-28').date()
fecha_fin = pd.to_datetime('2025-05-29').date()

# Crear bins de 2 días ajustados para corregir las fechas mal posicionadas
fechas = pd.date_range(fecha_inicio, fecha_fin).date
bins_fechas = [fechas[i] for i in range(0, len(fechas), 2)]
if bins_fechas[-1] != fecha_fin:
    bins_fechas.append(fecha_fin)

# Ajustar los datos para Vox y PSOE
for partido in partidos:
    if partido['partido'].iloc[0] == 'VOX':
        partido.loc[(partido['fecha'] == pd.to_datetime('2025-05-24').date()) | 
                    (partido['fecha'] == pd.to_datetime('2025-05-26').date()), 'fecha'] = pd.to_datetime('2025-05-25').date()
    if partido['partido'].iloc[0] == 'PSOE':
        partido.loc[(partido['fecha'] == pd.to_datetime('2025-05-26').date()) | 
                    (partido['fecha'] == pd.to_datetime('2025-05-28').date()), 'fecha'] = pd.to_datetime('2025-05-27').date()

# Preparar los datos para el gráfico
datos_partidos = []
datos_lideres = []

for partido in partidos:
    datos_periodo = []
    for i in range(len(bins_fechas)-1):
        tweets_periodo = partido[(partido['fecha'] >= bins_fechas[i]) & 
                                (partido['fecha'] <= bins_fechas[i+1])].shape[0]
        datos_periodo.append(tweets_periodo)
    datos_partidos.append(datos_periodo)

for lider in lideres:
    datos_periodo = []
    for i in range(len(bins_fechas)-1):
        tweets_periodo = lider[(lider['fecha'] >= bins_fechas[i]) & 
                              (lider['fecha'] <= bins_fechas[i+1])].shape[0]
        datos_periodo.append(tweets_periodo)
    datos_lideres.append(datos_periodo)

# Crear el gráfico
fig, ax = plt.subplots(figsize=(12, 8))
labels_x = [f"{bins_fechas[i]} - {bins_fechas[i+1]}" for i in range(len(bins_fechas)-1)]
# Anchura de las barras
bar_width = 0.15
r = np.arange(len(labels_x))

# Dibujar barras para cada partido y líder
for i in range(len(nombres_partidos)):
    # Barras de partidos
    ax.bar(r - bar_width*1.5 + (i * bar_width), datos_partidos[i], 
           width=bar_width, label=nombres_partidos[i], color=colores_partidos[i])
    # Barras de líderes
    ax.bar(r - bar_width*0.5 + (i * bar_width), datos_lideres[i], 
           width=bar_width, label=nombres_lideres[i], color=colores_lideres[i])

# Ajustar el gráfico
ax.set_xlabel('Periodo', fontsize=12)
ax.set_ylabel('Número de tweets', fontsize=12)
ax.set_title('Tweets sobre el apagón por partido y líder (28 abril - 28 mayo 2025)', fontsize=14)
ax.set_xticks(r)
ax.set_xticklabels(labels_x, rotation=45, ha='right')
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
#               nombre                   id           timestamp lider                                               body  blackout       fecha partido
# 23  Santiago Abascal  1921672524074467407 2025-05-11 23:03:27    si  Casi hace gracia ver al lehendakari" del PNV d...         1  2025-05-11     VOX
# 28  Santiago Abascal  1919526266199257304 2025-05-06 00:54:59    si  Y nos dejarán sin aceite… y sin luz.     Eso s...         1  2025-05-06     VOX
# 31  Santiago Abascal  1918407566482395148 2025-05-02 22:49:40    si  No estamos obligados a soportar las consecuenc...         1  2025-05-02     VOX
# 36  Santiago Abascal  1917555435680284799 2025-04-30 14:23:36    si  La responsabilidad directa es del señor" Pedro...         1  2025-04-30     VOX
# 37  Santiago Abascal  1917473464853610641 2025-04-30 08:57:53    si  El principal responsable es el corrupto Sánche...         1  2025-04-30     VOX

# %% [markdown]
# # **4. ANÁLISIS DE TEMAS (LDA)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import os
import seaborn as sns
from collections import Counter
import nltk
from nltk.corpus import stopwords
import warnings
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

# Configuraciones básicas
warnings.filterwarnings("ignore")
plt.style.use('seaborn-v0_8-whitegrid')
sns.set(font_scale=1.1)
nltk.download('stopwords', quiet=True)

# Directorio para resultados
RESULTADOS_DIR = 'resultados_lda_completo'
os.makedirs(RESULTADOS_DIR, exist_ok=True)

# Función para cargar datasets
def cargar_datasets():
    archivos = [
        "PEDRO SÁNCHEZ_filtered.csv",
        "ABASCAL_filtered.csv",
        "FEIJÓO_filtered.csv",
        "PP_filtered.csv",
        "PSOE_filtered.csv",
        "VOX_filtered.csv",
        "salidasumar_filtered.csv",
        "salidayolanda_filtered.csv"
    ]
    
    datasets = {}
    for archivo in archivos:
        nombre = archivo.replace("_filtered.csv", "")
        ruta = archivo
        try:
            datasets[nombre] = pd.read_csv(ruta)
            print(f"Cargado {nombre}: {len(datasets[nombre])} tweets")
        except Exception as e:
            print(f"Error al cargar {nombre}: {e}")
    
    return datasets

# Función para preprocesar texto
def preprocesar_texto(texto):
    if pd.isna(texto) or not isinstance(texto, str):
        return ""
    
    texto = texto.lower()
    texto = re.sub(r'https?://\S+|www\.\S+', '', texto)
    texto = re.sub(r'@\S+', '', texto)
    texto = re.sub(r'#(\w+)', r'\1', texto)
    texto = re.sub(r'[^\w\s]', '', texto)
    texto = re.sub(r'\d+', '', texto)
    texto = re.sub(r'\s+', ' ', texto).strip()
    
    return texto

# Obtener lista de stopwords mejorada
def obtener_stopwords():
    try:
        stop_words = set(stopwords.words('spanish'))
    except:
        stop_words = set()
    
    # Añadir stopwords adicionales comunes
    stop_words.update([
        'rt', 'xd', 'jaja', 'jajaja', 'si', 'no', 'q', 'd', 'k', 'x', 
        'el', 'la', 'los', 'las', 'un', 'una', 'y', 'o', 'pero', 'porque', 
        'como', 'cuando', 'donde', 'quien', 'que', 'este', 'esta', 'estos', 
        'estas', 'ese', 'esa', 'esos', 'esas', 'del', 'al', 'lo', 'le', 'les', 
        'me', 'te', 'se', 'nos', 'para', 'por', 'con', 'sin', 'sobre', 'entre', 
        'hasta', 'desde', 'contra', 'durante', 'mediante', 'según', 'a', 'ante', 
        'bajo', 'cabe', 'de', 'en', 'nuevo', 'gran', 'partido', 'vamos', 'país',
        'va', 'ser', 'hace', 'hacer', 'han', 'hay', 'hoy', 'así', 'cada', 'todo', "mayo", 
        "día", "consigue", "llegar", "días", "agenda", "buenos", "vuelta", "puede", 
        "pierdas", "partir", "menos", "puede", "zona", "roja", "vez", "siempre", "portavoz", 
        "sede", "aquí", "españa", "hacia", "años", "ahora", "todas", "europa",
        "mejor", "usted", "horas", "ver", "buenas", "compartiremos", "peor", "mientras", 
        "frente", "gracias", "ejecutiva", "josé", "compartimos", "españoles", "causa",
        "comisión", "gente"
    ])
    
    return stop_words

# Función para analizar temas con LDA y generar resultados
def analizar_temas(datasets, num_temas=5):
    # Obtener stopwords
    stop_words = obtener_stopwords()
    
    # Diccionario para almacenar resultados
    resultados = {}
    tema_principal_por_perfil = {}
    
    # Analizar cada perfil
    for nombre, df in datasets.items():
        print(f"\n{'='*50}")
        print(f"Analizando temas para: {nombre}")
        
        # Usar todos los datos
        df_completo = df.copy()
        
        if len(df_completo) < 5:
            print(f"Insuficientes tweets para {nombre}")
            continue
            
        # Preprocesar textos
        if 'body' in df_completo.columns:
            textos = df_completo['body'].fillna('').apply(preprocesar_texto).tolist()
            textos = [t for t in textos if len(t) > 10]  # Filtrar textos muy cortos
            
            if len(textos) < 5:
                print(f"Insuficientes textos válidos para {nombre}")
                continue
            
            # Vectorizar textos
            vectorizer = CountVectorizer(
                max_df=0.95,
                min_df=2,
                stop_words=list(stop_words),
                max_features=10000
            )
            
            X = vectorizer.fit_transform(textos)
            feature_names = vectorizer.get_feature_names_out()
            
            # Crear y entrenar modelo LDA
            lda = LatentDirichletAllocation(
                n_components=min(num_temas, max(2, len(textos)//50)),
                random_state=42,
                max_iter=30,
                learning_method='online',
                learning_offset=50.0,
                batch_size=128
            )
            
            lda.fit(X)
            
            # Guardar resultados generales
            resultados[nombre] = {
                'modelo': lda,
                'vectorizador': vectorizer,
                'feature_names': feature_names,
                'num_temas': lda.n_components,
                'num_tweets': len(textos)
            }
            
            # Extraer el tema principal (el primero)
            tema_principal = lda.components_[0]
            top_palabras_idx = tema_principal.argsort()[:-11:-1]  # Top 10 palabras
            top_palabras = [feature_names[i] for i in top_palabras_idx]
            
            # Guardar el tema principal para este perfil
            tema_principal_por_perfil[nombre] = top_palabras
            
            print(f"Tema principal: {', '.join(top_palabras)}")
            
            # Guardar en archivo de texto detallado
            with open(f'{RESULTADOS_DIR}/temas_{nombre.replace(" ", "_")}.txt', 'w', encoding='utf-8') as f:
                f.write(f"Análisis de temas para {nombre} (TODOS LOS TWEETS)\n")
                f.write(f"Total de tweets analizados: {len(textos)}\n\n")
                
                for tema_idx, tema in enumerate(lda.components_):
                    top_palabras_idx = tema.argsort()[:-31:-1]  # 30 palabras principales
                    top_palabras_tema = [feature_names[i] for i in top_palabras_idx]
                    f.write(f"Tema {tema_idx+1}: {', '.join(top_palabras_tema)}\n\n")
    
    # Generar tabla resumen de temas principales
    generar_tabla_temas_principales(tema_principal_por_perfil)
    
    return resultados

# Función para generar tabla de temas principales
def generar_tabla_temas_principales(tema_principal_por_perfil):
    print("\n" + "="*70)
    print(" TABLA DE TÉRMINOS PRINCIPALES POR PERFIL ".center(70, "="))
    print("="*70 + "\n")
    
    # Definir mapeo de nombres de perfiles
    nombre_display = {
        "salidasumar": "SUMAR",
        "salidayolanda": "YOLANDA DÍAZ"
    }
    
    # Definir orden de perfiles
    orden_perfiles = [
        "PSOE", 
        "PEDRO SÁNCHEZ", 
        "PP", 
        "FEIJÓO", 
        "VOX", 
        "ABASCAL", 
        "salidasumar", 
        "salidayolanda"
    ]
    
    # Crear filas para la tabla
    filas = []
    
    # Procesar perfiles en el orden deseado
    for perfil in orden_perfiles:
        # Buscar el perfil (considerando mayúsculas/minúsculas)
        perfil_encontrado = None
        for p in tema_principal_por_perfil.keys():
            if p.lower() == perfil.lower():
                perfil_encontrado = p
                break
        
        if perfil_encontrado:
            terminos = tema_principal_por_perfil[perfil_encontrado]
            
            # Determinar el nombre a mostrar
            nombre_mostrar = nombre_display.get(perfil_encontrado, perfil_encontrado)
            
            # Crear fila [Cuenta, Palabra1, Palabra2, Palabra3]
            fila = [nombre_mostrar]
            
            # Añadir los tres términos principales
            for i in range(3):
                if i < len(terminos):
                    fila.append(terminos[i])
                else:
                    fila.append("--")
            
            filas.append(fila)
    
    # Crear DataFrame
    columnas = ['Cuenta', 'Palabra 1', 'Palabra 2', 'Palabra 3']
    df_tabla = pd.DataFrame(filas, columns=columnas)
    
    # Guardar como CSV
    df_tabla.to_csv(f'{RESULTADOS_DIR}/tabla_temas_principales.csv', index=False)
    print(f"Tabla de temas principales guardada como CSV: {RESULTADOS_DIR}/tabla_temas_principales.csv")
    
    # Guardar como Excel
    df_tabla.to_excel(f'{RESULTADOS_DIR}/tabla_temas_principales.xlsx', index=False)
    print(f"Tabla de temas principales guardada como Excel: {RESULTADOS_DIR}/tabla_temas_principales.xlsx")
    
    # Mostrar tabla en consola
    print("\nTabla de términos principales por perfil:\n")
    print(df_tabla.to_string(index=False))
    
    # Crear visualización gráfica de la tabla
    plt.figure(figsize=(12, len(filas)*0.7 + 1.5))
    
    # Crear tabla como imagen
    ax = plt.subplot(111)
    ax.axis('off')
    
    # Crear tabla
    tabla = plt.table(
        cellText=df_tabla.values,
        colLabels=df_tabla.columns,
        cellLoc='center',
        loc='center',
        colWidths=[0.25, 0.25, 0.25, 0.25]
    )
    
    # Dar formato a la tabla
    tabla.auto_set_font_size(False)
    tabla.set_fontsize(11)
    tabla.scale(1, 1.5)
    
    # Colorear encabezados
    for j in range(len(columnas)):
        tabla[(0, j)].set_facecolor('#4472C4')
        tabla[(0, j)].set_text_props(color='white', fontweight='bold')
    
    # Colorear filas por familia política
    colores_politicos = {
        "PSOE": "#E61919",      # Rojo
        "PEDRO SÁNCHEZ": "#E61919",
        "PP": "#0055A4",        # Azul
        "FEIJÓO": "#0055A4",
        "VOX": "#5AC035",       # Verde
        "ABASCAL": "#5AC035",
        "SUMAR": "#6A1B9A",     # Morado
        "YOLANDA DÍAZ": "#6A1B9A"
    }
    
    for i, fila in enumerate(filas, 1):
        perfil = fila[0]  # Primera columna es el perfil
        
        if perfil in colores_politicos:
            color = colores_politicos[perfil]
            # Aplicar color con transparencia
            for j in range(len(columnas)):
                rgba = plt.matplotlib.colors.to_rgba(color, alpha=0.2)
                tabla[(i, j)].set_facecolor(rgba)
    
    plt.title('Términos principales por perfil político', fontsize=16)
    plt.tight_layout()
    
    # Guardar la tabla como imagen
    plt.savefig(f'{RESULTADOS_DIR}/tabla_temas_principales.png', dpi=300, bbox_inches='tight')
    plt.close()
    
    print(f"Visualización de tabla guardada como: {RESULTADOS_DIR}/tabla_temas_principales.png")

# Función principal
def analisis_lda_principal():
    print("\n" + "="*70)
    print(" ANÁLISIS LDA: TEMA PRINCIPAL POR PERFIL ".center(70, "="))
    print("="*70 + "\n")
    
    # Cargar datasets
    print("Cargando datasets...")
    datasets = cargar_datasets()
    
    if not datasets:
        print("No se pudieron cargar los datasets")
        return
    
    # Analizar temas
    print("\nExtrayendo tema principal de cada perfil político...")
    resultados = analizar_temas(datasets, num_temas=5)
    
    if resultados:
        print("\nAnálisis completado con éxito.")
        print(f"Los resultados están disponibles en el directorio '{RESULTADOS_DIR}'")
    else:
        print("\nNo se pudieron generar resultados del análisis")

# Ejecutar análisis
analisis_lda_principal()
# Out:
# ...
# ============== ANÁLISIS LDA: TEMA PRINCIPAL POR PERFIL ===============
# ...
#
# Cargando datasets...
# Cargado PEDRO SÁNCHEZ: 78 tweets
# Cargado ABASCAL: 46 tweets
# Cargado FEIJÓO: 79 tweets
# Cargado PP: 123 tweets
# Cargado PSOE: 313 tweets
# Cargado VOX: 189 tweets
# Cargado salidasumar: 163 tweets
# Cargado salidayolanda: 96 tweets
#
# Extrayendo tema principal de cada perfil político...
#
# ...
# Analizando temas para: PEDRO SÁNCHEZ
# Tema principal: derechos, seguridad, derecho, noche, fuerza, suministro, trabajadores, historia, compromiso, gobierno
#
# ...
# Analizando temas para: ABASCAL
# Tema principal: gobierno, esperanza, apagón, sánchez, woke, consecuencias, décadas, solidaridad, socialista, verdad
#
# ...
# Analizando temas para: FEIJÓO
# Tema principal: gobierno, apagón, cambio, necesita, enhorabuena, mayoría, congreso, millones, felicidades, preocupación
#
# ...
# Analizando temas para: PP
# Tema principal: gobierno, sánchez, pedro, apagón, presidente, corrupción, trenes, merece, bien, sabía
#
# ...

# %% [markdown]
# # **5. MODELO DE RED NEURONAL**

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

# Cargar el modelo y el tokenizer de RoBERTuito entrenado para análisis de sentimiento
modelo = "pysentimiento/robertuito-sentiment-analysis"
tokenizer = AutoTokenizer.from_pretrained(modelo)
model = AutoModelForSequenceClassification.from_pretrained(modelo)

# Crear pipeline para clasificación
analizador = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)
# Out:
# Device set to use cpu

# %% [markdown]
# EJEMPLO

# %%
# Frase de ejemplo
frase1 = "Estoy harto de todo esto"
frase2 = "Me encanta la programación en Python"
frase3 = "Hoy hace sol"

# Clasificar
resultado = analizador(frase1)
print(resultado)
resultado = analizador(frase2)
print(resultado)
resultado = analizador(frase3)
print(resultado)
# Out:
# [{'label': 'NEG', 'score': 0.9645105600357056}]
# [{'label': 'POS', 'score': 0.9567092061042786}]
# [{'label': 'NEU', 'score': 0.560903787612915}]

# %% [markdown]
# Como se puede apreciar, el modelo de red neuronal da una salida del tipo:
# - (sentimiento, score)
# donde sentimiento puede ser NEG (negativo), NEU (neutral) o POS (positivo) y score es un número entre 0 y 1, indicando una puntuación asignada por el modelo al sentimiento inferido.
#
# Por tanto, no se trata de un modelo de regresión, o de clasificación binaria, sino de un modelo de clasificación multiclase, donde la salida es la tupla (sentimiento, score).
#
# De cara a poder agregar valores de score, es necesario transformar de acuerdo a nuestro interés. No podemos simplemente sumar los scores, ya que el score por si solo no indica el sentimiento de la frase. En nuestro caso queremos diferenciar entre sentimiento (positivo o negativo) y neutralidad. Por tanto, tiene sentido utilizar el score como un peso y asignar un valor numérico a las etiquetas:
#
# - NEG = 1
# - NEU = -1
# - POS = 1
#
# Como solo queremos diferenciar entre sentimiento y no sentimiento (para la hipótesis 3), asignamos el valor 1 a NEG y POS, y -1 a NEU. De esta forma, si la frase es positiva o negativa, el score se suma al resultado final, mientras que si es neutral, se resta.
#
# Cada frase quedaría entonces caracterizada por la tupla (sentimiento, score) y una puntuación calculada como:
# $$
# \text{puntuacion} = \text{sentimiento} \cdot \text{score}
# $$
# siendo sentimiento el valor numérico asignado a la etiqueta (-1 o 1).

# %% [markdown]
# # **6. ANÁLISIS DE SENTIMIENTOS (HIPÓTESIS 2)**

# %%
# Generamos un conjunto de datos de ejemplo
import pandas as pd
import numpy as np

lider_a_partido={}
data = pd.read_csv("base_conjunta.csv")
# data["Partido"]

# %%
lider_a_partido ={'Santiago Abascal':"VOX", 'Feijóo':"PP", 'Pedro Sánchez':"PSOE", 'PP':"PP", 'PSOE':"PSOE",
       'Sumar':"Sumar", 'Yolanda Díaz':"Sumar", 'VOX':'VOX'}
oposicion = set(['PP', 'VOX', 'Sumar'])
# Añadimos el nombre del partido a cada líder
data["Partido"] = data["nombre"].map(lider_a_partido)
# Añadimos si se trata de oposición
data["Oposicion"] = data["Partido"].apply(lambda x: x in oposicion)
# Filtramos para que solo sea del blackout
data = data[data["blackout"]==1]

# %%
data.head()
# Out:
#     nombre                   id            timestamp lider                                               body  blackout origen Partido  Oposicion
# 3     PSOE  1927672851718443216  2025-05-28 12:26:36    no  La vicepresidenta tercera y ministra para la T...         1   PSOE    PSOE      False
# 8     PSOE  1927635483401629700  2025-05-28 09:58:07    no  No es responsable difundir bulos.    No es res...         1   PSOE    PSOE      False
# 171   PSOE  1921317242634936679  2025-05-10 23:31:41    no  Calma y sosiego.    Tenemos que poner todos lo...         1   PSOE    PSOE      False
# 229   PSOE  1920020694651326590  2025-05-07 09:39:40    no  ¿Sabéis cuál es la solución de aquellos que ac...         1   PSOE    PSOE      False
# 231   PSOE  1920018607846654411  2025-05-07 09:31:22    no  Se está trabajando con prudencia‚ rigor y tran...         1   PSOE    PSOE      False

# %%
from tqdm import tqdm
sentimiento = []
score = []
puntuacion = []
dic = {"NEU":-1, "POS":1, "NEG":1}

for frase in tqdm(data["body"]):
  try:
    resultado = analizador(frase)
  except Exception as e:
    print(f"Error procesando la frase: {frase}")
    print(f"Error: {e}")
  # Guardamos la etiqueta de sentimiento
  sentimiento.append(resultado[0]['label'])
  # guardamos el score
  score.append(resultado[0]['score'])
  
  # calculamos la puntuación multiplicando el score por el valor de la etiqueta
  puntuacion.append(dic[resultado[0]['label']]*resultado[0]['score'])

  
data["Sentimiento"] = sentimiento
data["Score"] = score
data["Puntuacion"] = puntuacion
df = pd.DataFrame(data)
# Out:
# 100%|██████████| 89/89 [00:53<00:00,  1.65it/s]

# %%
data.head()
# Out:
#     nombre                   id            timestamp lider                                               body  blackout origen Partido  Oposicion Sentimiento     Score  Puntuacion
# 3     PSOE  1927672851718443216  2025-05-28 12:26:36    no  La vicepresidenta tercera y ministra para la T...         1   PSOE    PSOE      False         NEG  0.745632    0.745632
# 8     PSOE  1927635483401629700  2025-05-28 09:58:07    no  No es responsable difundir bulos.    No es res...         1   PSOE    PSOE      False         NEG  0.945394    0.945394
# 171   PSOE  1921317242634936679  2025-05-10 23:31:41    no  Calma y sosiego.    Tenemos que poner todos lo...         1   PSOE    PSOE      False         NEU  0.720822   -0.720822
# 229   PSOE  1920020694651326590  2025-05-07 09:39:40    no  ¿Sabéis cuál es la solución de aquellos que ac...         1   PSOE    PSOE      False         NEG  0.925196    0.925196
# ...

# %%
print("Resultados")
print(df)
print("\n")

# Sumamos puntuacion agrupado por partido
print("Resultados por partido (sumando la puntuacion)")
df_partido = df.groupby("Partido")["Puntuacion"].sum().reset_index()
print(df_partido)
print("\n")
# Sumamos puntuacion agrupado por partido y lider
print("Resultados por partido y lider (sumando la puntuacion)")
df_partido_lider = df.groupby(["Partido", "lider"])["Puntuacion"].sum().reset_index()
print(df_partido_lider)
print("\n")
# Out:
# Resultados
#                 nombre                                                 id                 timestamp lider                                               body  blackout         origen Partido  Oposicion Sentimiento     Score  Puntuacion
# 3                 PSOE                                1927672851718443216       2025-05-28 12:26:36    no  La vicepresidenta tercera y ministra para la T...         1           PSOE    PSOE      False         NEG  0.745632    0.745632
# 8                 PSOE                                1927635483401629700       2025-05-28 09:58:07    no  No es responsable difundir bulos.    No es res...         1           PSOE    PSOE      False         NEG  0.945394    0.945394
# 171               PSOE                                1921317242634936679       2025-05-10 23:31:41    no  Calma y sosiego.    Tenemos que poner todos lo...         1           PSOE    PSOE      False         NEU  0.720822   -0.720822
# ...

# %%
# Confianza de la oposicion que sea negativo
# Tweets negativos de la oposicion
df_oposicion = df[df["Oposicion"] == True]
df_oposicion_neg = df_oposicion[df_oposicion["Sentimiento"] == "NEG"]


confianza = df_oposicion_neg.shape[0] / df_oposicion.shape[0]
print("Confianza de la oposicion que sea negativo: ", confianza)

# Lift
lift = confianza / (df[df["Sentimiento"] == "NEG"].shape[0] / df.shape[0])
print("Tweets negativos de la oposicion")
print(df_oposicion_neg.shape[0])
print("Tweets de la oposicion")
print(df_oposicion.shape[0])
print("Total de tweets negativos")
print(df[df["Sentimiento"] == "NEG"].shape[0])
print("Lift: ", lift)
# Out:
# Confianza de la oposicion que sea negativo:  0.819672131147541
# Tweets negativos de la oposicion
# 50
# Tweets de la oposicion
# 61
# Total de tweets negativos
# 58
# Lift:  1.2577727529677785

# %% [markdown]
# # **7. COMPROBACIÓN HIPÓTESIS 3**

# %%
data_ps = data[data["nombre"]=="Pedro Sánchez"]
data_nf = data[data["nombre"]=="Feijóo"]
data_ab = data[data["nombre"]=="Santiago Abascal"]
data_yd = data[data["nombre"]=="Yolanda Díaz"]
data_su = data[data["nombre"]=="Sumar"]
data_pp = data[data["nombre"]=="PP"]
data_vox = data[data["nombre"]=="VOX"]
data_psoe = data[data["nombre"]=="PSOE"]

# %% [markdown]
# HIPÓTESIS DE NORMALIDAD

# %%
from scipy.stats import kstest, ttest_ind, mannwhitneyu

# Aplicar test de normalidad a cada dataset usando {}

# Aplicar test de hipótesis por pares (en Puntuación)
# Usando el modelo {modelo}


# Comprobar normalidad con Kolmogórov-Smirnov
normalidad_pp = kstest(data_pp["Puntuacion"], 'norm')
normalidad_psoe = kstest(data_psoe["Puntuacion"], 'norm')
normalidad_su = kstest(data_su["Puntuacion"], 'norm')
normalidad_vox = kstest(data_vox["Puntuacion"], 'norm')

normalidad_ps = kstest(data_ps["Puntuacion"], 'norm')
normalidad_nf = kstest(data_nf["Puntuacion"], 'norm')
normalidad_ab = kstest(data_ab["Puntuacion"], 'norm')
normalidad_yd = kstest(data_yd["Puntuacion"], 'norm')

print("Normalidad PP:", normalidad_pp.pvalue)
print("Normalidad Feijóo:", normalidad_nf.pvalue)

print("Normalidad PSOE:", normalidad_psoe.pvalue)
print("Normalidad Pedro Sánchez:", normalidad_ps.pvalue)

print("Normalidad Sumar:", normalidad_su.pvalue)
print("Normalidad Yolanda Díaz:", normalidad_yd.pvalue)

print("Normalidad VOX:", normalidad_vox.pvalue)
print("Normalidad Santiago Abascal:", normalidad_ab.pvalue)
# Out:
# Normalidad PP: 1.5322860793919555e-06
# Normalidad Feijóo: 0.0010292755340720204
# Normalidad PSOE: 0.23144435329093105
# Normalidad Pedro Sánchez: 0.514053619789839
# Normalidad Sumar: 0.13120141970899024
# Normalidad Yolanda Díaz: 0.3731006033206783
# Normalidad VOX: 0.000416179553712324
# Normalidad Santiago Abascal: 6.367634344120648e-07

# %% [markdown]
# HIPÓTESIS DE MEDIAS

# %%
# PSOE y PS son normales
t_test_result_psoe = ttest_ind(data_psoe["Puntuacion"], data_ps["Puntuacion"])
print("Medias de puntuación")
print("PSOE:", data_psoe["Puntuacion"].mean())
print("Pedro Sánchez:", data_ps["Puntuacion"].mean())
print("Prueba t de Student entre PSOE y Pedro Sánchez:", t_test_result_psoe.pvalue)
print("\n")

# Sumar y YD son normales
t_test_result_sumar = ttest_ind(data_su["Puntuacion"], data_yd["Puntuacion"])
print("Medias de puntuación")
print("Sumar:", data_su["Puntuacion"].mean())
print("Yolanda Díaz:", data_yd["Puntuacion"].mean())
print("Prueba t de Student entre Sumar y Yolanda Díaz:", t_test_result_sumar.pvalue)
print("\n")

# PP y Feijoo no son normales
mann_whitney_result_pp = mannwhitneyu(data_pp["Puntuacion"], data_nf["Puntuacion"])
print("Medias de puntuación")
print("PP:", data_pp["Puntuacion"].mean())
print("Feijóo:", data_nf["Puntuacion"].mean())
print("Prueba Mann-Whitney U entre PP y Feijóo:", mann_whitney_result_pp.pvalue)
print("\n")

# VOX y Santiago Abascal no son normales
mann_whitney_result_vox = mannwhitneyu(data_vox["Puntuacion"], data_ab["Puntuacion"])
print("Medias de puntuación")
print("VOX:", data_vox["Puntuacion"].mean())
print("Santiago Abascal:", data_ab["Puntuacion"].mean())
print("Prueba Mann-Whitney U entre VOX y Santiago Abascal:", mann_whitney_result_vox.pvalue)
print("\n")
# Out:
# Medias de puntuación
# PSOE: 0.09084520902898577
# Pedro Sánchez: 0.0914052039384842
# Prueba t de Student entre PSOE y Pedro Sánchez: 0.9984749257677841
#
#
# Medias de puntuación
# Sumar: 0.4661735355854034
# Yolanda Díaz: 0.8906804919242859
# Prueba t de Student entre Sumar y Yolanda Díaz: 0.5610650036212265
#
#
# Medias de puntuación
# PP: 0.6784259610705905
# Feijóo: 0.6139514495929083
# Prueba Mann-Whitney U entre PP y Feijóo: 0.8822111206344694
#
#
# Medias de puntuación
# VOX: 0.6310379413458017
# Santiago Abascal: 0.8843869815270106
# Prueba Mann-Whitney U entre VOX y Santiago Abascal: 0.8490153628243157

# %% [markdown]
# BOXPLOT

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Configurar estilo de los gráficos
sns.set_theme(style="whitegrid")

# Crear figura con 4 subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# 1. PSOE vs Pedro Sánchez
sns.boxplot(data=data_psoe, x="Partido", y="Puntuacion", ax=axs[0, 0], color="lightblue", label="PSOE")
sns.boxplot(data=data_ps, x="nombre", y="Puntuacion", ax=axs[0, 0], color="lightgreen", label="Pedro Sánchez")
axs[0, 0].set_title("Boxplot: PSOE vs Pedro Sánchez")
axs[0, 0].legend()

# 2. Sumar vs Yolanda Díaz
sns.boxplot(data=data_su, x="Partido", y="Puntuacion", ax=axs[0, 1], color="lightblue", label="Sumar")
sns.boxplot(data=data_yd, x="nombre", y="Puntuacion", ax=axs[0, 1], color="lightgreen", label="Yolanda Díaz")
axs[0, 1].set_title("Boxplot: Sumar vs Yolanda Díaz")
axs[0, 1].legend()

# 3. PP vs Feijóo
sns.boxplot(data=data_pp, x="Partido", y="Puntuacion", ax=axs[1, 0], color="lightblue", label="PP")
sns.boxplot(data=data_nf, x="nombre", y="Puntuacion", ax=axs[1, 0], color="lightgreen", label="Feijóo")
axs[1, 0].set_title("Boxplot: PP vs Feijóo")
axs[1, 0].legend()

# 4. VOX vs Santiago Abascal
sns.boxplot(data=data_vox, x="Partido", y="Puntuacion", ax=axs[1, 1], color="lightblue", label="VOX")
sns.boxplot(data=data_ab, x="nombre", y="Puntuacion", ax=axs[1, 1], color="lightgreen", label="Santiago Abascal")
axs[1, 1].set_title("Boxplot: VOX vs Santiago Abascal")
axs[1, 1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# HISTOGRAMAS

# %%
# Configurar estilo de los gráficos
sns.set_theme(style="whitegrid")

# Crear figura con 4 subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# 1. PSOE vs Pedro Sánchez
sns.histplot(data=data_psoe, x="Puntuacion", ax=axs[0, 0], color="lightblue", label="PSOE", kde=True)
sns.histplot(data=data_ps, x="Puntuacion", ax=axs[0, 0], color="lightgreen", label="Pedro Sánchez", kde=True)
axs[0, 0].set_title("Histograma: PSOE vs Pedro Sánchez")
axs[0, 0].legend()

# 2. Sumar vs Yolanda Díaz
sns.histplot(data=data_su, x="Puntuacion", ax=axs[0, 1], color="lightblue", label="Sumar", kde=True)
sns.histplot(data=data_yd, x="Puntuacion", ax=axs[0, 1], color="lightgreen", label="Yolanda Díaz", kde=True, bins=30)
axs[0, 1].set_title("Histograma: Sumar vs Yolanda Díaz")
axs[0, 1].legend()

# 3. PP vs Feijóo
sns.histplot(data=data_pp, x="Puntuacion", ax=axs[1, 0], color="lightblue", label="PP", kde=True)
sns.histplot(data=data_nf, x="Puntuacion", ax=axs[1, 0], color="lightgreen", label="Feijóo", kde=True)
axs[1, 0].set_title("Histograma: PP vs Feijóo")
axs[1, 0].legend()

# 4. VOX vs Santiago Abascal
sns.histplot(data=data_vox, x="Puntuacion", ax=axs[1, 1], color="lightblue", label="VOX", kde=True)
sns.histplot(data=data_ab, x="Puntuacion", ax=axs[1, 1], color="lightgreen", label="Santiago Abascal", kde=True)
axs[1, 1].set_title("Histograma: VOX vs Santiago Abascal")
axs[1, 1].legend()

plt.tight_layout()
plt.show()
